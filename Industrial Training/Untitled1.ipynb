# %%
import pandas as pd

# %%
data_set_2008 = pd.read_csv(r"C:\Users\manas\Downloads\ipl\IPL - Player Performance Dataset\Most Runs Over\Most Runs Over - 2008.csv")

# %%
data_set_2008.head()
# Out:
#    POS             Player  Runs  BF      SR  4s  6s Against  \
# 0    1    Virender Sehwag    30   6  500.00   3   3     DEC
# 1    2  Sanath Jayasuriya    26   5  520.00   2   3     CSK
# 2    3        MF Maharoof    26   5  520.00   0   4      RR
# 3    4       Rohit Sharma    26   6  433.33   3   2      DC
# 4    5       Shane Watson    26   6  433.33   5   1     RCB
#
#                                 Venue     Match Date
# 0  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008
# 1                    Wankhede Stadium    14 May 2008
# 2              Sawai Mansingh Stadium    11 May 2008
# 3  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008
# 4              M. Chinnaswamy Stadium  26 April 2008

# %%
IPL_Data = {}

for year in range(2008,2022):
    IPL_Data[year] = pd.read_csv(rf"C:\Users\manas\Downloads\ipl\IPL - Player Performance Dataset\Most Runs Over\Most Runs Over - {year}.csv")
for i,j in IPL_Data.items():
    print(i,"-->",j)
# Out:
# 2008 -->      POS                 Player  Runs  BF      SR  4s  6s Against  \
# 0      1        Virender Sehwag    30   6  500.00   3   3     DEC
# 1      2      Sanath Jayasuriya    26   5  520.00   2   3     CSK
# 2      3            MF Maharoof    26   5  520.00   0   4      RR
# 3      4           Rohit Sharma    26   6  433.33   3   2      DC
# 4      5           Shane Watson    26   6  433.33   5   1     RCB
# ..   ...                    ...   ...  ..     ...  ..  ..     ...
# 145  146         Gautam Gambhir    13   5  260.00   3   0     RCB
# 146  147  Subramaniam Badrinath    13   5  260.00   0   2    PBKS
# 147  148         Michael Hussey    13   4  325.00   1   1    PBKS
# 148  149           Yusuf Pathan    13   4  325.00   3   0    PBKS
# 149  150        Stephen Fleming    13   5  260.00   1   1     RCB
#
#                                   Venue     Match Date
# 0    Rajiv Gandhi Intl. Cricket Stadium  22 April 2008
# ...

# %%
for year,df in IPL_Data.items():
    df["Season"] = year

# %%
data_set_2008.head()
# Out:
#    POS             Player  Runs  BF      SR  4s  6s Against  \
# 0    1    Virender Sehwag    30   6  500.00   3   3     DEC
# 1    2  Sanath Jayasuriya    26   5  520.00   2   3     CSK
# 2    3        MF Maharoof    26   5  520.00   0   4      RR
# 3    4       Rohit Sharma    26   6  433.33   3   2      DC
# 4    5       Shane Watson    26   6  433.33   5   1     RCB
#
#                                 Venue     Match Date
# 0  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008
# 1                    Wankhede Stadium    14 May 2008
# 2              Sawai Mansingh Stadium    11 May 2008
# 3  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008
# 4              M. Chinnaswamy Stadium  26 April 2008

# %%
IPL_2008_2022 = pd.concat(IPL_Data.values(), ignore_index = True)
IPL_2008_2022.sample(10)
IPL_2008_2022.head()
# Out:
#    POS             Player  Runs  BF      SR  4s  6s Against  \
# 0    1    Virender Sehwag    30   6  500.00   3   3     DEC
# 1    2  Sanath Jayasuriya    26   5  520.00   2   3     CSK
# 2    3        MF Maharoof    26   5  520.00   0   4      RR
# 3    4       Rohit Sharma    26   6  433.33   3   2      DC
# 4    5       Shane Watson    26   6  433.33   5   1     RCB
#
#                                 Venue     Match Date  Season
# 0  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008    2008
# 1                    Wankhede Stadium    14 May 2008    2008
# 2              Sawai Mansingh Stadium    11 May 2008    2008
# 3  Rajiv Gandhi Intl. Cricket Stadium  22 April 2008    2008
# 4              M. Chinnaswamy Stadium  26 April 2008    2008

# %%
IPL_2008_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   POS         2100 non-null   int64
#  1   Player      2100 non-null   object
#  2   Runs        2100 non-null   int64
#  3   BF          2100 non-null   int64
#  4   SR          2100 non-null   float64
#  5   4s          2100 non-null   int64
#  6   6s          2100 non-null   int64
#  7   Against     2100 non-null   object
#  8   Venue       2100 non-null   object
#  9   Match Date  2100 non-null   object
#  10  Season      2100 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 180.6+ KB

# %%
IPL_2008_2022.shape
# Out:
# (2100, 11)
